# %%
a ={1,3,5,8,3,7}
b ={0,False,1,5}
print(len(a))
print(type(a))
# Out:
# 5
# <class 'set'>

# %%
a ={1,3,5,8,3,7}
a.add(10)
print(a)
# Out:
# {1, 3, 5, 7, 8, 10}

# %%
a ={1,3,5,8,3,7}
a.remove(8)
print(a)
# Out:
# {1, 3, 5, 7}

# %%
a ={1,3,5,8,3,7}
b ={0,False,1,5}

c=a.union(b)
print(c)
c= a&b
print(c)
c= a.difference(b)
print(c)
# Out:
# {0, 1, 3, 5, 7, 8}
# {1, 5}
# {8, 3, 7}

# %%
a ={1,3,5,8,3,7}
for i in a:
  print(i)
  if i== 5:
    break
# Out:
# 1
# 3
# 5

# %%
a = {1, 3, 5, 8, 3, 7}
b = [2, 3, 4]

result = list(a) + b
print(result)
# Out:
# [1, 3, 5, 7, 8, 2, 3, 4]

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}

print(type(emp))
print(len(emp))
# Out:
# <class 'dict'>
# 8

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}
print(emp["type"])
print(emp["type"]["developer"])
print(emp["type"]["developer"][1])
print(emp["age"])
# Out:
# {'developer': ['ios', 'android']}
# ['ios', 'android']
# android
# 40

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}

emp["parmanent"] = False
print(emp["parmanent"])
# Out:
# False

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}

emp["gender"] = "male"
print(emp["gender"])
# Out:
# male

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}

emp.pop("age")
print(emp)
# Out:
# {'name': 'A', 'type': {'developer': ['ios', 'android']}, 'parmanent': True, 'salary': 30000.5, 100: (1, 2, 3), 45: {True, 5, 6, 7}, True: 1}

# %%
emp = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["ios", "android"]},
    "parmanent": True,
    "salary": 30000.5,
    100: (1, 2, 3),
    45: {5, 6, True, 7, 1},
    True: 1
}

print(emp.keys())
print(emp.items())
print(emp.values())
# Out:
# dict_keys(['name', 'age', 'type', 'parmanent', 'salary', 100, 45, True])
# dict_items([('name', 'A'), ('age', 40), ('type', {'developer': ['ios', 'android']}), ('parmanent', True), ('salary', 30000.5), (100, (1, 2, 3)), (45, {True, 5, 6, 7}), (True, 1)])
# dict_values(['A', 40, {'developer': ['ios', 'android']}, True, 30000.5, (1, 2, 3), {True, 5, 6, 7}, 1])

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

print(myfamily)
