# %% [markdown]
# Create a table using dictionary

# %%
data = {"year" : [2010, 2011, 2012, 2010, 2011, 2012, 2010, 2011, 2012],
 "team": ["FCBarcelona","FCBarcelona","FCBarcelona", "RMadrid", "RMadrid", " RMadrid", "ValenciaCF", "Valencia CF"," ValenciaCF"],
 "wins": [30, 28, 32, 29, 32, 26, 21, 17, 19],
  "draws": [6, 7, 4, 5, 4, 7, 8, 10, 8],
 "losses": [2, 3, 2, 4, 2, 5, 9, 11, 11]}

# %%
football = pd.DataFrame(data, columns = ["year","team","wins","draws","losses"])
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011  Valencia CF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
football = football.sort_values("year",ascending=True)
football
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 3  2010      RMadrid    29      5       4
# 6  2010   ValenciaCF    21      8       9
# 1  2011  FCBarcelona    28      7       3
# 4  2011      RMadrid    32      4       2
# 7  2011  Valencia CF    17     10      11
# 2  2012  FCBarcelona    32      4       2
# 5  2012      RMadrid    26      7       5
# 8  2012   ValenciaCF    19      8      11

# %%
football.drop(["team"],axis=1)
# Out:
#    year  wins  draws  losses
# 0  2010    30      6       2
# 3  2010    29      5       4
# 6  2010    21      8       9
# 1  2011    28      7       3
# 4  2011    32      4       2
# 7  2011    17     10      11
# 2  2012    32      4       2
# 5  2012    26      7       5
# 8  2012    19      8      11

# %%
import pandas as pd
df = pd.read_csv('/content/null_values.csv')
df
# Out:
#     Name   Age  Height  Weight  result  study.h
# 0   John  28.0   170.0    70.0    3.50      6.0
# 1   Anna  29.0   165.0    60.0    4.00      8.0
# 2   Mark  35.0   167.0    80.0    3.20      4.0
# 3   Lucy  24.0   160.0    55.0    2.75      5.0
# 4  Peter   NaN     NaN     NaN     NaN      NaN

# %% [markdown]
# using is null function

# %%
df.isnull()
# Out:
#     Name    Age  Height  Weight  result  study.h
# 0  False  False   False   False   False    False
# 1  False  False   False   False   False    False
# 2  False  False   False   False   False    False
# 3  False  False   False   False   False    False
# 4  False   True    True    True    True     True

# %%
df.isnull().sum()/len(df) * 100
# Out:
# Name        0.0
# Age        20.0
# Height     20.0
# Weight     20.0
# result     20.0
# study.h    20.0
# dtype: float64

# %% [markdown]
# Drop null value

# %%
df_drop = df.dropna()
df_drop
# Out:
#    Name   Age  Height  Weight  result  study.h
# 0  John  28.0   170.0    70.0    3.50      6.0
# 1  Anna  29.0   165.0    60.0    4.00      8.0
# 2  Mark  35.0   167.0    80.0    3.20      4.0
# 3  Lucy  24.0   160.0    55.0    2.75      5.0

# %% [markdown]
# Drop String type row

# %%
df = df.drop(['Name'],axis=1)
df
# Out:
#     Age  Height  Weight  result  study.h
# 0  28.0   170.0    70.0    3.50      6.0
# 1  29.0   165.0    60.0    4.00      8.0
# 2  35.0   167.0    80.0    3.20      4.0
# 3  24.0   160.0    55.0    2.75      5.0
# 4   NaN     NaN     NaN     NaN      NaN

# %% [markdown]
# Null value filled by mean

# %%
df= df.fillna(df.mean())
df
# Out:
#     Age  Height  Weight  result  study.h
# 0  28.0   170.0   70.00  3.5000     6.00
# 1  29.0   165.0   60.00  4.0000     8.00
# 2  35.0   167.0   80.00  3.2000     4.00
# 3  24.0   160.0   55.00  2.7500     5.00
# 4  29.0   165.5   66.25  3.3625     5.75

# %%
df.corr()
# Out:
#               Age    Height    Weight    result   study.h
# Age      1.000000  0.558234  0.892836  0.272345 -0.300537
# Height   0.558234  1.000000  0.733196  0.517372  0.069655
# Weight   0.892836  0.733196  1.000000  0.068006 -0.506137
# result   0.272345  0.517372  0.068006  1.000000  0.822544
# study.h -0.300537  0.069655 -0.506137  0.822544  1.000000

# %%
x=[14.6,24.3,24.9,27,27.2,27.4,28.2,28.8,29.9,30.7,31.5,31.6,32.3,32.8, 33.3,33.6,34.3,36.9,38.3,44]

# %%
li = pd.DataFrame(x)

li.mean()
# Out:
# 0    30.58
# dtype: float64

# %%
li.std()
# Out:
# 0    6.028406
# dtype: float64

# %%
li.skew()
# Out:
# 0   -0.374028
# dtype: float64

# %%
li.kurtosis()
# Out:
# 0    2.269117
# dtype: float64
